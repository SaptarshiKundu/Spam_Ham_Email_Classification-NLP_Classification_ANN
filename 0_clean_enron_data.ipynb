# %% [markdown]
# ### Importing necessary libraries

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ### Reading initial raw data

# %%
df = pd.read_csv('data/spam_ham_enron_dataset.csv')

# %%
df
# Out:
#        Message_ID                                            Subject  \
# 0               0                       christmas tree farm pictures
# 1               1                           vastar resources , inc .
# 2               2                       calpine daily gas nomination
# 3               3                                         re : issue
# 4               4                          meter 7268 nov allocation
# ...           ...                                                ...
# 33711       33711  = ? iso - 8859 - 1 ? q ? good _ news _ c = eda...
# 33712       33712  all prescript medicines are on special . to be...
# 33713       33713              the next generation online pharmacy .
# 33714       33714                     bloow in 5 - 10 times the time
# 33715       33715                   dear sir , i am interested in it
#
#                                                  Message Spam/Ham        Date
# 0                                                    NaN      ham  1999-12-10
# 1      gary , production from the high island larger ...      ham  1999-12-13
# 2                 - calpine daily gas nomination 1 . doc      ham  1999-12-14
# 3      fyi - see note below - already done .\nstella\...      ham  1999-12-14
# 4      fyi .\n- - - - - - - - - - - - - - - - - - - -...      ham  1999-12-14
# ...                                                  ...      ...         ...
# 33711  hello , welcome to gigapharm onlinne shop .\np...     spam  2005-07-29
# 33712  i got it earlier than expected and it was wrap...     spam  2005-07-29
# 33713  are you ready to rock on ? let the man in you ...     spam  2005-07-30
# 33714  learn how to last 5 - 10 times longer in\nbed ...     spam  2005-07-30
# 33715  hi : )\ndo you need some softwares ? i can giv...     spam  2005-07-31
#
# [33716 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33716 entries, 0 to 33715
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Message_ID  33716 non-null  int64
#  1   Subject     33427 non-null  object
#  2   Message     33345 non-null  object
#  3   Spam/Ham    33716 non-null  object
#  4   Date        33716 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 1.3+ MB

# %% [markdown]
# ### Dropping unnecessary columns

# %%
df.drop(columns=["Message_ID", "Date"], inplace=True)
df
# Out:
#                                                  Subject  \
# 0                           christmas tree farm pictures
# 1                               vastar resources , inc .
# 2                           calpine daily gas nomination
# 3                                             re : issue
# 4                              meter 7268 nov allocation
# ...                                                  ...
# 33711  = ? iso - 8859 - 1 ? q ? good _ news _ c = eda...
# 33712  all prescript medicines are on special . to be...
# 33713              the next generation online pharmacy .
# 33714                     bloow in 5 - 10 times the time
# 33715                   dear sir , i am interested in it
#
#                                                  Message Spam/Ham
# 0                                                    NaN      ham
# 1      gary , production from the high island larger ...      ham
# 2                 - calpine daily gas nomination 1 . doc      ham
# 3      fyi - see note below - already done .\nstella\...      ham
# 4      fyi .\n- - - - - - - - - - - - - - - - - - - -...      ham
# ...                                                  ...      ...
# 33711  hello , welcome to gigapharm onlinne shop .\np...     spam
# 33712  i got it earlier than expected and it was wrap...     spam
# 33713  are you ready to rock on ? let the man in you ...     spam
# 33714  learn how to last 5 - 10 times longer in\nbed ...     spam
# 33715  hi : )\ndo you need some softwares ? i can giv...     spam
#
# [33716 rows x 3 columns]

# %% [markdown]
# ### Label encoding target labels
# #### 0 : Not Spam
# #### 1 : Spam

# %%
df.value_counts("Spam/Ham")
# Out:
# Spam/Ham
# spam    17171
# ham     16545
# dtype: int64

# %%
label_encoding_dict = {'spam': 1, 'ham': 0}

# %%
df['label'] = df['Spam/Ham'].map(label_encoding_dict)

# %%
df
# Out:
#                                                  Subject  \
# 0                           christmas tree farm pictures
# 1                               vastar resources , inc .
# 2                           calpine daily gas nomination
# 3                                             re : issue
# 4                              meter 7268 nov allocation
# ...                                                  ...
# 33711  = ? iso - 8859 - 1 ? q ? good _ news _ c = eda...
# 33712  all prescript medicines are on special . to be...
# 33713              the next generation online pharmacy .
# 33714                     bloow in 5 - 10 times the time
# 33715                   dear sir , i am interested in it
#
#                                                  Message Spam/Ham  label
# 0                                                    NaN      ham      0
# 1      gary , production from the high island larger ...      ham      0
# 2                 - calpine daily gas nomination 1 . doc      ham      0
# 3      fyi - see note below - already done .\nstella\...      ham      0
# 4      fyi .\n- - - - - - - - - - - - - - - - - - - -...      ham      0
# ...                                                  ...      ...    ...
# 33711  hello , welcome to gigapharm onlinne shop .\np...     spam      1
# 33712  i got it earlier than expected and it was wrap...     spam      1
# 33713  are you ready to rock on ? let the man in you ...     spam      1
# 33714  learn how to last 5 - 10 times longer in\nbed ...     spam      1
# 33715  hi : )\ndo you need some softwares ? i can giv...     spam      1
#
# [33716 rows x 4 columns]

# %%
df.value_counts('label')
# Out:
# label
# 1    17171
# 0    16545
# dtype: int64

# %%
df.drop(columns=['Spam/Ham'], inplace=True)
df
# Out:
#                                                  Subject  \
# 0                           christmas tree farm pictures
# 1                               vastar resources , inc .
# 2                           calpine daily gas nomination
# 3                                             re : issue
# 4                              meter 7268 nov allocation
# ...                                                  ...
# 33711  = ? iso - 8859 - 1 ? q ? good _ news _ c = eda...
# 33712  all prescript medicines are on special . to be...
# 33713              the next generation online pharmacy .
# 33714                     bloow in 5 - 10 times the time
# 33715                   dear sir , i am interested in it
#
#                                                  Message  label
# 0                                                    NaN      0
# 1      gary , production from the high island larger ...      0
# 2                 - calpine daily gas nomination 1 . doc      0
# 3      fyi - see note below - already done .\nstella\...      0
# 4      fyi .\n- - - - - - - - - - - - - - - - - - - -...      0
# ...                                                  ...    ...
# 33711  hello , welcome to gigapharm onlinne shop .\np...      1
# 33712  i got it earlier than expected and it was wrap...      1
# 33713  are you ready to rock on ? let the man in you ...      1
# 33714  learn how to last 5 - 10 times longer in\nbed ...      1
# 33715  hi : )\ndo you need some softwares ? i can giv...      1
#
# [33716 rows x 3 columns]

# %% [markdown]
# ### Checking for NaN values in Subject and Message

# %%
df.Message.isna().sum()
# Out:
# 371

# %%
df.Subject.isna().sum()
# Out:
# 289

# %% [markdown]
# ### Dropping rows where both Subject and Message is NaN

# %%
df.dropna(subset=['Subject', 'Message'], how='all', inplace=True)
df
# Out:
#                                                  Subject  \
# 0                           christmas tree farm pictures
# 1                               vastar resources , inc .
# 2                           calpine daily gas nomination
# 3                                             re : issue
# 4                              meter 7268 nov allocation
# ...                                                  ...
# 33711  = ? iso - 8859 - 1 ? q ? good _ news _ c = eda...
# 33712  all prescript medicines are on special . to be...
# 33713              the next generation online pharmacy .
# 33714                     bloow in 5 - 10 times the time
# 33715                   dear sir , i am interested in it
#
#                                                  Message  label
# 0                                                    NaN      0
# 1      gary , production from the high island larger ...      0
# 2                 - calpine daily gas nomination 1 . doc      0
# 3      fyi - see note below - already done .\nstella\...      0
# 4      fyi .\n- - - - - - - - - - - - - - - - - - - -...      0
# ...                                                  ...    ...
# 33711  hello , welcome to gigapharm onlinne shop .\np...      1
# 33712  i got it earlier than expected and it was wrap...      1
# 33713  are you ready to rock on ? let the man in you ...      1
# 33714  learn how to last 5 - 10 times longer in\nbed ...      1
# 33715  hi : )\ndo you need some softwares ? i can giv...      1
#
# [33665 rows x 3 columns]

# %%
df.Message.isna().sum(), df.Subject.isna().sum()
# Out:
# (320, 238)

# %% [markdown]
# ### NaN value for Subject replaced with "(no_subject)"
# ### NaN value for Message replaced with "(no_message_text)"

# %%
df_new = df.copy()
df_new
# Out:
#                                                  Subject  \
# 0                           christmas tree farm pictures
# 1                               vastar resources , inc .
# 2                           calpine daily gas nomination
# 3                                             re : issue
# 4                              meter 7268 nov allocation
# ...                                                  ...
# 33711  = ? iso - 8859 - 1 ? q ? good _ news _ c = eda...
# 33712  all prescript medicines are on special . to be...
# 33713              the next generation online pharmacy .
# 33714                     bloow in 5 - 10 times the time
# 33715                   dear sir , i am interested in it
#
#                                                  Message  label
# 0                                                    NaN      0
# 1      gary , production from the high island larger ...      0
# 2                 - calpine daily gas nomination 1 . doc      0
# 3      fyi - see note below - already done .\nstella\...      0
# 4      fyi .\n- - - - - - - - - - - - - - - - - - - -...      0
# ...                                                  ...    ...
# 33711  hello , welcome to gigapharm onlinne shop .\np...      1
# 33712  i got it earlier than expected and it was wrap...      1
# 33713  are you ready to rock on ? let the man in you ...      1
# 33714  learn how to last 5 - 10 times longer in\nbed ...      1
# 33715  hi : )\ndo you need some softwares ? i can giv...      1
#
# [33665 rows x 3 columns]

# %%
df_new['Subject'].fillna("(no_subject)", inplace=True)
df_new
# Out:
#                                                  Subject  \
# 0                           christmas tree farm pictures
# 1                               vastar resources , inc .
# 2                           calpine daily gas nomination
# 3                                             re : issue
# 4                              meter 7268 nov allocation
# ...                                                  ...
# 33711  = ? iso - 8859 - 1 ? q ? good _ news _ c = eda...
# 33712  all prescript medicines are on special . to be...
# 33713              the next generation online pharmacy .
# 33714                     bloow in 5 - 10 times the time
# 33715                   dear sir , i am interested in it
#
#                                                  Message  label
# 0                                                    NaN      0
# 1      gary , production from the high island larger ...      0
# 2                 - calpine daily gas nomination 1 . doc      0
# 3      fyi - see note below - already done .\nstella\...      0
# 4      fyi .\n- - - - - - - - - - - - - - - - - - - -...      0
# ...                                                  ...    ...
# 33711  hello , welcome to gigapharm onlinne shop .\np...      1
# 33712  i got it earlier than expected and it was wrap...      1
# 33713  are you ready to rock on ? let the man in you ...      1
# 33714  learn how to last 5 - 10 times longer in\nbed ...      1
# 33715  hi : )\ndo you need some softwares ? i can giv...      1
#
# [33665 rows x 3 columns]

# %%
df_new.Message.isna().sum(), df_new.Subject.isna().sum()
# Out:
# (320, 0)

# %%
df_new['Message'].fillna("(no_message_text)", inplace=True)
df_new
# Out:
#                                                  Subject  \
# 0                           christmas tree farm pictures
# 1                               vastar resources , inc .
# 2                           calpine daily gas nomination
# 3                                             re : issue
# 4                              meter 7268 nov allocation
# ...                                                  ...
# 33711  = ? iso - 8859 - 1 ? q ? good _ news _ c = eda...
# 33712  all prescript medicines are on special . to be...
# 33713              the next generation online pharmacy .
# 33714                     bloow in 5 - 10 times the time
# 33715                   dear sir , i am interested in it
#
#                                                  Message  label
# 0                                      (no_message_text)      0
# 1      gary , production from the high island larger ...      0
# 2                 - calpine daily gas nomination 1 . doc      0
# 3      fyi - see note below - already done .\nstella\...      0
# 4      fyi .\n- - - - - - - - - - - - - - - - - - - -...      0
# ...                                                  ...    ...
# 33711  hello , welcome to gigapharm onlinne shop .\np...      1
# 33712  i got it earlier than expected and it was wrap...      1
# 33713  are you ready to rock on ? let the man in you ...      1
# 33714  learn how to last 5 - 10 times longer in\nbed ...      1
# 33715  hi : )\ndo you need some softwares ? i can giv...      1
#
# [33665 rows x 3 columns]

# %%
df_new.Message.isna().sum(), df_new.Subject.isna().sum()
# Out:
# (0, 0)

# %% [markdown]
# ### Resetting index

# %%
df_new.reset_index(inplace=True)
df_new
# Out:
#        index                                            Subject  \
# 0          0                       christmas tree farm pictures
# 1          1                           vastar resources , inc .
# 2          2                       calpine daily gas nomination
# 3          3                                         re : issue
# 4          4                          meter 7268 nov allocation
# ...      ...                                                ...
# 33660  33711  = ? iso - 8859 - 1 ? q ? good _ news _ c = eda...
# 33661  33712  all prescript medicines are on special . to be...
# 33662  33713              the next generation online pharmacy .
# 33663  33714                     bloow in 5 - 10 times the time
# 33664  33715                   dear sir , i am interested in it
#
#                                                  Message  label
# 0                                      (no_message_text)      0
# 1      gary , production from the high island larger ...      0
# 2                 - calpine daily gas nomination 1 . doc      0
# 3      fyi - see note below - already done .\nstella\...      0
# 4      fyi .\n- - - - - - - - - - - - - - - - - - - -...      0
# ...                                                  ...    ...
# 33660  hello , welcome to gigapharm onlinne shop .\np...      1
# 33661  i got it earlier than expected and it was wrap...      1
# 33662  are you ready to rock on ? let the man in you ...      1
# 33663  learn how to last 5 - 10 times longer in\nbed ...      1
# 33664  hi : )\ndo you need some softwares ? i can giv...      1
#
# [33665 rows x 4 columns]

# %%
df_new.drop(columns=['index'], inplace=True)
df_new
# Out:
#                                                  Subject  \
# 0                           christmas tree farm pictures
# 1                               vastar resources , inc .
# 2                           calpine daily gas nomination
# 3                                             re : issue
# 4                              meter 7268 nov allocation
# ...                                                  ...
# 33660  = ? iso - 8859 - 1 ? q ? good _ news _ c = eda...
# 33661  all prescript medicines are on special . to be...
# 33662              the next generation online pharmacy .
# 33663                     bloow in 5 - 10 times the time
# 33664                   dear sir , i am interested in it
#
#                                                  Message  label
# 0                                      (no_message_text)      0
# 1      gary , production from the high island larger ...      0
# 2                 - calpine daily gas nomination 1 . doc      0
# 3      fyi - see note below - already done .\nstella\...      0
# 4      fyi .\n- - - - - - - - - - - - - - - - - - - -...      0
# ...                                                  ...    ...
# 33660  hello , welcome to gigapharm onlinne shop .\np...      1
# 33661  i got it earlier than expected and it was wrap...      1
# 33662  are you ready to rock on ? let the man in you ...      1
# 33663  learn how to last 5 - 10 times longer in\nbed ...      1
# 33664  hi : )\ndo you need some softwares ? i can giv...      1
#
# [33665 rows x 3 columns]

# %% [markdown]
# ### Exporting DataFrame to CSV

# %%
df_new.to_csv("data/enron_spam_ham_email_clean.csv", index=False)
